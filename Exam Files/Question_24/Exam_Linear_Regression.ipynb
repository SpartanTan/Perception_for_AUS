# %%
import numpy as np
import open3d as o3d
from matplotlib import pyplot as plt
from sklearn.linear_model import LinearRegression
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Linear regression
# Given the dataset x, y apply linear regression to find the model of the form: y = ax + b
#
# What are the values of "a" and "b" in that model?
#
# Recall:
# ```{Python}
# x_reshaped = x.reshape(-1, 1) #fit needs data in this shape
# # Initialize and fit model
# lm = LinearRegression()
# model = lm.fit(input, target)
# ```

# %%
x = np.loadtxt('lr_x.txt', dtype=float)
y = np.loadtxt('lr_y.txt', dtype=float)
plt.figure(figsize=(8, 6))
plt.plot(x, y, 'ro')   # scatter plot showing actual data
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x_r = x.reshape(-1,1) #fit needs x in this shape
# Initialise and fit model
lm = LinearRegression()
model = lm.fit(x_r, y)
a = lm.get_params
print(a)
# Out:
# <bound method BaseEstimator.get_params of LinearRegression()>

# %%
predicted = lm.predict(x_r)
plt.figure(figsize=(8, 6))
plt.plot(x_r, predicted)     # regression line
plt.plot(x_r, y, 'ro')   # scatter plot showing actual data
plt.title('Actual vs Predicted')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
print(x)
print(predicted)
# Out:
# [58.820262 52.000786 54.89369  61.204466 59.33779  45.113611 54.750442
#  49.243214 49.483906 52.052993 50.720218 57.271368 53.805189 50.608375
#  52.219316 51.668372 57.470395 48.974209 51.565339 45.729521 37.235051
#  53.268093 54.322181 46.289175 61.348773 42.728172 50.228793 49.064081
#  57.663896 57.346794 50.774737 51.890813 45.561071 40.096018 48.260439
#  50.781745 56.151453 56.011899 48.063366 48.488486 44.757235 42.89991
#  41.468649 59.753877 47.451739 47.809628 43.736023 53.887452 41.930511
#  48.936299 45.522667 51.934512 47.445974 44.096839 49.859089 52.141659
#  50.332586 51.512359 46.82839  48.186294 46.637698 48.202234 45.934269
#  41.368587 50.887131 47.991095 41.849008 52.313911 45.463508 50.259727
#  53.645453 50.644915 55.697003 43.825871 52.011708 46.57595  45.646014
#  47.105752 48.442237 50.280827 44.174251 54.504132 52.328312 42.318782
#  57.441261 59.479446 55.893898 49.100376 44.646237 55.272259 47.984115
#  56.112225 51.041375 54.883195 51.781832 53.532866 50.0525   58.929352
#  50.63456  52.009947]
# [51.96510526 48.24249396 49.82167059 53.26659306 52.24761313 44.48292716
#  49.74347446 46.73719227 46.86858107 48.27099268 47.54345829 51.11959597
#  49.22748034 47.48240551 48.36178498 48.06103601 51.22824071 46.59034799
#  48.00479242 44.81913973 40.18218374 48.93429071 49.50969561 45.1246433
#  53.34536727 43.18076521 47.27519952 46.63940726 51.33386891 51.16076947
#  47.57321909 48.18246196 44.72718635 41.74392662 46.20071567 47.57704462
#  50.50825747 50.43207782 46.09313758 46.32520182 44.28838885 43.27451344
#  42.49321758 52.47474644 45.75926302 45.95462724 43.73093028 49.27238602
#  42.74533852 46.5696537  44.7062224  48.20631635 45.75611602 43.9278923
#  47.07338573 48.31939362 47.33185798 47.97587173 45.41898965 46.16024144
#  45.31489482 46.16894276 44.93090744 42.43859579 47.63457266 46.05368633
#  42.70084771 48.41342244 44.67392872 47.29208575 49.14028375 47.50235194
#  50.26018259 43.77997645 48.24845605 45.28118786 44.77355498 45.57039585
#  46.29995545 47.30360381 43.97014991 49.60901891 48.42128365 42.95728765
#  51.21233706 52.32494022 50.36766351 46.65921995 44.22779733 50.0283236
#  46.04987609 50.48684371 47.71877128 49.81594158 48.12297148 49.07882483
#  47.17896481 52.02465525 47.49669936 48.24749476]
